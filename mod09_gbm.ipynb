# %%
# packages
import os
import joblib
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from sklearn.model_selection import train_test_split 
from sklearn.ensemble import GradientBoostingRegressor as GBR
from sklearn.model_selection import GridSearchCV

# set seed
seed = 5151

# %% [markdown]
# ### You'll need the California housing data (CAhousing.csv) to complete this exercise. Your goal is to predict the median house value.

# %%
CAhousing = pd.read_csv('data/CAhousing.csv')
CAhousing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -120.45     34.66                 7.0       3329.0           504.0
# 1    -114.64     34.83                10.0       2502.0           573.0
# 2    -117.24     32.74                43.0       2216.0           375.0
# 3    -122.43     37.76                52.0       3771.0          1017.0
# 4    -118.02     34.13                34.0       1966.0           319.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0      1462.0       452.0         4.7875            198300.0      NEAR OCEAN
# 1      1152.0       481.0         1.7062             86800.0          INLAND
# 2       918.0       388.0         5.5289            297700.0      NEAR OCEAN
# 3      1575.0       921.0         3.5655            427300.0        NEAR BAY
# 4       980.0       297.0         7.7307            429000.0          INLAND

# %%
CAhousing.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
CAhousing.shape
# Out:
# (15480, 10)

# %% [markdown]
# ### There is a single categorical variable in this dataset that we will convert to a series of binary variables.

# %%
CAhousing['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     6857
# INLAND        4933
# NEAR OCEAN    1974
# NEAR BAY      1712
# ISLAND           4
# Name: count, dtype: int64

# %%
# create binary variables for levels which have enough records, using '<1H OCEAN' as base.
CAhousing['ocean_prox_inland'] = (CAhousing.ocean_proximity == 'INLAND').astype(int)
CAhousing['ocean_prox_nearocean'] = (CAhousing.ocean_proximity == 'NEAR OCEAN').astype(int)
CAhousing['ocean_prox_nearbay'] = (CAhousing.ocean_proximity == 'NEAR BAY').astype(int)

# check for intended outcome
print(CAhousing['ocean_prox_inland'].value_counts())
print(CAhousing['ocean_prox_nearocean'].value_counts())
print(CAhousing['ocean_prox_nearbay'].value_counts())
# Out:
# ocean_prox_inland
# 0    10547
# 1     4933
# Name: count, dtype: int64
# ocean_prox_nearocean
# 0    13506
# 1     1974
# Name: count, dtype: int64
# ocean_prox_nearbay
# 0    13768
# 1     1712
# Name: count, dtype: int64

# %%
indep_vars = ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 
              'total_bedrooms', 'population', 'households', 'median_income', 
              'ocean_prox_inland', 'ocean_prox_nearocean', 'ocean_prox_nearbay']

X = CAhousing[indep_vars]
y = CAhousing['median_house_value']

# %%
X_train, X_test, y_train, y_test, Train, Test = train_test_split(X, y, CAhousing, 
                                                                 random_state = seed, 
                                                                 test_size = 0.33, 
                                                                 shuffle = True)

# %%
X_train.corr().style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_a38ca_row0_col0, #T_a38ca_row1_col1, #T_a38ca_row2_col2, #T_a38ca_row3_col3, #T_a38ca_row4_col4, #T_a38ca_row5_col5, #T_a38ca_row6_col6, #T_a38ca_row7_col7, #T_a38ca_row8_col8, #T_a38ca_row9_col9, #T_a38ca_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a38ca_row0_col1, #T_a38ca_row1_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_a38ca_row0_col2, #T_a38ca_row2_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_a38ca_row0_col3, #T_a38ca_row3_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_a38ca_row0_col4, #T_a38ca_row4_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_a38ca_row0_col5, #T_a38ca_row5_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_a38ca_row0_col6, #T_a38ca_row6_col0, #T_a38ca_row7_col10, #T_a38ca_row10_col7 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_a38ca_row0_col7, #T_a38ca_row3_col9, #T_a38ca_row7_col0, #T_a38ca_row9_col3 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_a38ca_row0_col8, #T_a38ca_row1_col4, #T_a38ca_row4_col1, #T_a38ca_row5_col10, #T_a38ca_row8_col0, #T_a38ca_row10_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_a38ca_row0_col9, #T_a38ca_row9_col0 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_a38ca_row0_col10, #T_a38ca_row10_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_a38ca_row1_col2, #T_a38ca_row2_col1, #T_a38ca_row2_col9, #T_a38ca_row3_col8, #T_a38ca_row8_col3, #T_a38ca_row9_col2 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_a38ca_row1_col3, #T_a38ca_row3_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_a38ca_row1_col5, #T_a38ca_row5_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_a38ca_row1_col6, #T_a38ca_row6_col1 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_a38ca_row1_col7, #T_a38ca_row7_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_a38ca_row1_col8, #T_a38ca_row8_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_a38ca_row1_col9, #T_a38ca_row9_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_a38ca_row1_col10, #T_a38ca_row10_col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_a38ca_row2_col3, #T_a38ca_row3_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_a38ca_row2_col4, #T_a38ca_row4_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_a38ca_row2_col5, #T_a38ca_row5_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_a38ca_row2_col6, #T_a38ca_row6_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_a38ca_row2_col7, #T_a38ca_row7_col2, #T_a38ca_row9_col10, #T_a38ca_row10_col9 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_a38ca_row2_col8, #T_a38ca_row7_col8, #T_a38ca_row8_col2, #T_a38ca_row8_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_a38ca_row2_col10, #T_a38ca_row10_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_a38ca_row3_col4, #T_a38ca_row4_col3 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_a38ca_row3_col5, #T_a38ca_row5_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_a38ca_row3_col6, #T_a38ca_row6_col3 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_a38ca_row3_col7, #T_a38ca_row7_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_a38ca_row3_col10, #T_a38ca_row5_col8, #T_a38ca_row8_col5, #T_a38ca_row10_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_a38ca_row4_col5, #T_a38ca_row5_col4 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_a38ca_row4_col6, #T_a38ca_row6_col4 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_a38ca_row4_col7, #T_a38ca_row4_col8, #T_a38ca_row5_col9, #T_a38ca_row7_col4, #T_a38ca_row8_col4, #T_a38ca_row9_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_a38ca_row4_col9, #T_a38ca_row5_col7, #T_a38ca_row6_col9, #T_a38ca_row7_col5, #T_a38ca_row9_col4, #T_a38ca_row9_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_a38ca_row4_col10, #T_a38ca_row6_col10, #T_a38ca_row10_col4, #T_a38ca_row10_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_a38ca_row5_col6, #T_a38ca_row6_col5 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_a38ca_row6_col7, #T_a38ca_row7_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_a38ca_row6_col8, #T_a38ca_row8_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_a38ca_row7_col9, #T_a38ca_row9_col7 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_a38ca_row8_col9, #T_a38ca_row9_col8 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_a38ca_row8_col10, #T_a38ca_row10_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# </style>
# <table id="T_a38ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a38ca_level0_col0" class="col_heading level0 col0" >longitude</th>
#       <th id="T_a38ca_level0_col1" class="col_heading level0 col1" >latitude</th>
#       <th id="T_a38ca_level0_col2" class="col_heading level0 col2" >housing_median_age</th>
#       <th id="T_a38ca_level0_col3" class="col_heading level0 col3" >total_rooms</th>
#       <th id="T_a38ca_level0_col4" class="col_heading level0 col4" >total_bedrooms</th>
#       <th id="T_a38ca_level0_col5" class="col_heading level0 col5" >population</th>
#       <th id="T_a38ca_level0_col6" class="col_heading level0 col6" >households</th>
#       <th id="T_a38ca_level0_col7" class="col_heading level0 col7" >median_income</th>
#       <th id="T_a38ca_level0_col8" class="col_heading level0 col8" >ocean_prox_inland</th>
#       <th id="T_a38ca_level0_col9" class="col_heading level0 col9" >ocean_prox_nearocean</th>
#       <th id="T_a38ca_level0_col10" class="col_heading level0 col10" >ocean_prox_nearbay</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_
#
#        median_house_value  ocean_prox_inland  ocean_prox_nearocean  \
# count        10371.000000       10371.000000          10371.000000
# mean        206399.612284           0.323787              0.124771
# std         115215.425942           0.467943              0.330475
# min          14999.000000           0.000000              0.000000
# 25%         118750.000000           0.000000              0.000000
# 50%         179800.000000           0.000000              0.000000
# 75%         264000.000000           1.000000              0.000000
# max         500001.000000           1.000000              1.000000
#
#        ocean_prox_nearbay
# count        10371.000000
# mean             0.109247
# std              0.311964
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max              1.000000

# %% [markdown]
# ### We see that `total_bedrooms` has a few missing values, and it is also very correlated with `total_rooms`. Because of this, it's easiest to remove it from our training set.

# %%
indep_vars.remove("total_bedrooms")

# %% [markdown]
# ### We'll define some helper functions here:
# (1) to calculate MSE, and
# (2) to display the improvement of a GBM on test data as additional trees are constructed.

# %%
def mse(y, y_hat):
    """
    Calculate the MSE of a model given actual and predicted values
    """
    # calculate the residual error for each individual record
    resid = y - y_hat
    # square the residual (hence "squared error")
    sq_resid = resid**2
    # calculate the sum of squared errors
    SSR = sum(sq_resid)
    # divide by the number of records to get the mean squared error
    MSE = SSR / y.shape[0]
    return MSE

def gbm_progress(model_name, X_test, y_test):
    """
    Plot the 'progress' of a GBM on a test set to assess robustness
    """
    test_error = np.zeros_like(model_name.train_score_)
    for idx, y_ in enumerate(model_name.staged_predict(X_test)):
        test_error[idx] = np.mean((y_test - y_)**2)

    plot_idx = np.arange(model_name.train_score_.shape[0])
    ax = subplots(figsize=(8,8))[1]
    ax.plot(plot_idx,
            model_name.train_score_,
            'b',
            label='Training')
    ax.plot(plot_idx,
            test_error,
            'r',
            label='Test')
    ax.legend();

# %% [markdown]
# ### Build a basic GBM first.

# %%
# Documentation: https://scikit-learn.org/dev/modules/generated/sklearn.ensemble.GradientBoostingRegressor.html

gbm_basic = GBR(learning_rate=0.1,
               n_estimators=250,
               max_depth=10,
               min_samples_split=2,
               subsample=1,
               random_state=seed)

gbm_basic.fit(X_train[indep_vars], y_train)
# Out:
# GradientBoostingRegressor(max_depth=10, n_estimators=250, random_state=5151,
#                           subsample=1)

# %%
y_hat_basic = gbm_basic.predict(X_test[indep_vars])

mse_basic = mse(y_test, y_hat_basic)
print('test mse: ',mse_basic)
# Out:
# test mse:  2524578849.5044518

# %% [markdown]
# ### When we plot the performance of the model on training and test data, we see that performance no longer improves after a certain number of trees (in this case, between 50-100 trees).

# %%
gbm_progress(gbm_basic, X_test[indep_vars], y_test)

# %% [markdown]
# ### Now you'll have the chance to choose optimal hyperparameters to build a better GBM.
# Once the candidate hyperparameters are chosen, use 5-fold cross-validation to decide which collection of hyperparameters are best.

# %%
def get_best_gbm(X, y, results_path="gridsearch_results.pkl", force_retrain=False):
    """
    Runs GridSearchCV OR loads precomputed results if available.

    Parameters:
        X, y : training data
        results_path : where results are saved
        force_retrain : if True, ignore saved file and rerun

    Returns:
        best_model : fitted model
        best_params : dict
    """

    # Fast Version: load existing results
    if os.path.exists(results_path) and not force_retrain:
        data = joblib.load(results_path)
        print("Loaded precomputed GridSearchCV results.")
        return data["best_model"], data["best_params"]

    # Slow Version: run grid search via cross-validation
    print("Running GridSearchCV...")

    ## Define model
    gbm_cv = GBR(random_state=seed)

    ## Define hyperparameter grid. Choose between 1 and 4 values to test for each one.
    #fillin
    param_grid = {
        "n_estimators": [100, 200],
        "learning_rate": [0.05, 0.1],
        "max_depth": [3, 5],
        "min_samples_leaf": [1, 5],
        "subsample": [0.8, 1.0]
    }

    grid_search = GridSearchCV(
        estimator=gbm_cv,
        param_grid=param_grid,
        cv=5,                               # number of folds
        scoring="neg_mean_squared_error",   # how we evaluate which model is best
        n_jobs=-1,                          # use all available cores
        verbose=3
    )

    grid_search.fit(X, y)

    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    ## Save results. Gradescope will use this file instead of rerunning the grid search.
    joblib.dump({
        "best_model": best_model,
        "best_params": best_params,
        "cv_results": grid_search.cv_results_
    }, results_path)

    print(f"Saved results to {results_path}")

    return best_model, best_params

# %%
# Identify best model
best_model, best_params = get_best_gbm(X_train[indep_vars], y_train, force_retrain=False)

print("Best parameters:")
print(best_params)
# Out:
# Running GridSearchCV...
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-3515827639.542 total time=   1.6s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-3963235443.852 total time=   1.7s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-3844455115.988 total time=   1.5s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-3859282703.461 total time=   1.5s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-3662354167.573 total time=   1.4s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-3975298368.918 total time=   1.7s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-3573052109.053 total time=   2.1s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-3856241139.339 total time=   2.0s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-3833828082.979 total time=   1.8s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-3783509583.568 total time=   1.8s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-2920246873.136 total time=   3.1s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-3276035785.691 total time=   3.3s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-3215483213.310 total time=   3.0s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-3098956702.787 total time=   3.2s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-3090975937.120 total time=   3.6s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-3323079049.944 total time=   4.4s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-2930622166.140 total time=   3.6s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-3100417744.106 total time=   3.6s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-3236885753.605 total time=   5.0s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-3108205496.906 total time=   4.8s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-3956221582.096 total time=   1.7s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-3522092194.858 total time=   1.6s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-3846977198.489 total time=   1.5s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-3861327220.679 total time=   1.4s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-3651771376.891 total time=   1.6s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-3981271156.304 total time=   1.9s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-3577240541.652 total time=   2.1s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-3819680303.527 total time=   1.8s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-3831183984.316 total time=   1.8s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-3729828665.877 total time=   1.8s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-3317849592.405 total time=   3.2s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-2928759561.490 total time=   2.9s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-3081555978.462 total time=   3.0s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-3190582205.869 total time=   3.1s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-3060066352.379 total time=   3.0s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-3343040834.202 total time=   3.6s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-2951604318.705 total time=   3.7s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-3090322932.124 total time=   3.7s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-3221879739.924 total time=   3.6s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_leaf=5, n_estimators=200, subsample=1.0;, score=-3089851135.169 total time=   3.6s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-3035698439.385 total time=   2.4s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-2837558155.419 total time=   2.3s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-2875046868.422 total time=   2.7s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-2918511637.488 total time=   2.6s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=0.8;, score=-2883908585.109 total time=   2.4s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-3067160748.043 total time=   2.8s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-2805908016.606 total time=   3.1s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-2978550603.446 total time=   3.0s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-2962236063.503 total time=   2.8s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=100, subsample=1.0;, score=-2970654201.013 total time=   2.9s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-2686370105.701 total time=   4.9s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-2562027732.078 total time=   4.9s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-2435025125.181 total time=   5.0s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-2580557668.355 total time=   4.8s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=0.8;, score=-2521794971.574 total time=   5.0s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-2758755702.856 total time=   5.9s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-2519594512.768 total time=   5.7s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-2545052957.908 total time=   5.8s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-2548693729.938 total time=   5.8s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=1, n_estimators=200, subsample=1.0;, score=-2595963018.286 total time=   5.9s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-3056420307.348 total time=   2.3s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-2791447480.135 total time=   2.5s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-2847226023.795 total time=   2.4s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-2972352283.261 total time=   2.5s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=5, n_estimators=100, subsample=0.8;, score=-2882913459.809 total time=   2.5s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-3042309285.517 total time=   2.9s
# [CV 2/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-2841022134.666 total time=   2.9s
# [CV 3/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-2811691765.405 total time=   2.8s
# [CV 4/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-2966568163.973 total time=   2.8s
# [CV 5/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=5, n_estimators=100, subsample=1.0;, score=-2919677207.883 total time=   3.0s
# [CV 1/5] END learning_rate=0.05, max_depth=5, min_samples_leaf=5, n_estimators=200, subsample=0.8;, score=-